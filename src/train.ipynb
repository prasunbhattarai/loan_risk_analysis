# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install -U scikit-learn
# !pip install xgboost
# Out:
# Requirement already satisfied: pandas in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.26.0 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: seaborn in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from seaborn) (2.3.5)
# Requirement already satisfied: pandas>=1.2 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from seaborn) (3.0.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit-learn in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from scikit-learn) (2.3.5)
# Requirement already satisfied: scipy>=1.10.0 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: xgboost in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (3.2.0)
# Requirement already satisfied: numpy in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from xgboost) (2.3.5)
# Requirement already satisfied: scipy in d:\projects\loan\loan_risk_analysis\.venv\lib\site-packages (from xgboost) (1.17.1)
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_error
from sklearn.preprocessing import StandardScaler
from xgboost import XGBRegressor
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('../dataset/Loan.csv')

# %%
print(df.head(5))
# Out:
#   ApplicationDate  Age  AnnualIncome  CreditScore EmploymentStatus  \
# 0      2018-01-01   45         39948          617         Employed
# 1      2018-01-02   38         39709          628         Employed
# 2      2018-01-03   47         40724          570         Employed
# 3      2018-01-04   58         69084          545         Employed
# 4      2018-01-05   37        103264          594         Employed
#
#   EducationLevel  Experience  LoanAmount  LoanDuration MaritalStatus  ...  \
# 0         Master          22       13152            48       Married  ...
# 1      Associate          15       26045            48        Single  ...
# 2       Bachelor          26       17627            36       Married  ...
# 3    High School          34       37898            96        Single  ...
# 4      Associate          17        9184            36       Married  ...
#
#    MonthlyIncome UtilityBillsPaymentHistory  JobTenure  NetWorth  \
# 0    3329.000000                   0.724972         11    126928
# 1    3309.083333                   0.935132          3     43609
# 2    3393.666667                   0.872241          6      5205
# 3    5757.000000                   0.896155          5     99452
# 4    8605.333333                   0.941369          5    227019
#
#    BaseInterestRate  InterestRate  MonthlyLoanPayment  TotalDebtToIncomeRatio  \
# 0          0.199652      0.227590          419.805992                0.181077
# 1          0.207045      0.201077          794.054238                0.389852
# 2          0.217627      0.212548          666.406688                0.462157
# 3          0.300398      0.300911         1047.506980                0.313098
# 4          0.197184      0.175990          330.179140                0.070210
#
#   LoanApproved  RiskScore
# 0            0       49.0
# 1            0       52.0
# 2            0       52.0
# 3            0       54.0
# 4            1       36.0
#
# [5 rows x 36 columns]

# %%
correlations =  df.corr(numeric_only=True)
colormap = sns.color_palette('BrBG',10)
fig, ax = plt.subplots(figsize = (20,20))
sns.heatmap(
    correlations,
    cmap=colormap,
    annot=True,
      fmt=".2f")
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ApplicationDate             20000 non-null  str
#  1   Age                         20000 non-null  int64
#  2   AnnualIncome                20000 non-null  int64
#  3   CreditScore                 20000 non-null  int64
#  4   EmploymentStatus            20000 non-null  str
#  5   EducationLevel              20000 non-null  str
#  6   Experience                  20000 non-null  int64
#  7   LoanAmount                  20000 non-null  int64
#  8   LoanDuration                20000 non-null  int64
#  9   MaritalStatus               20000 non-null  str
#  10  NumberOfDependents          20000 non-null  int64
#  11  HomeOwnershipStatus         20000 non-null  str
#  12  MonthlyDebtPayments         20000 non-null  int64
#  13  CreditCardUtilizationRate   20000 non-null  float64
#  14  NumberOfOpenCreditLines     20000 non-null  int64
#  15  NumberOfCreditInquiries     20000 non-null  int64
#  16  DebtToIncomeRatio           20000 non-null  float64
#  17  BankruptcyHistory           20000 non-null  int64
#  18  LoanPurpose                 20000 non-null  str
#  19  PreviousLoanDefaults        20000 non-null  int64
#  20  PaymentHistory              20000 non-null  int64
#  21  LengthOfCreditHistory       20000 non-null  int64
#  22  SavingsAccountBalance       20000 non-null  int64
#  23  CheckingAccountBalance      20000 non-null  int64
#  24  TotalAssets                 20000 non-null  int64
#  25  TotalLiabilities            20000 non-null  int64
#  26  MonthlyIncome               20000 non-null  float64
#  27  UtilityBillsPaymentHistory  20000 non-null  float64
#  28  JobTenure                   20000 non-null  int64
#  29  NetWorth                    20000 non-null  int64
#  30  BaseInterestRate            20000 non-null  float64
#  31  InterestRate                20000 non-null  float64
#  32  MonthlyLoanPayment          20000 non-null  float64
#  33  TotalDebtToIncomeRatio      20000 non-null  float64
#  34  LoanApproved                20000 non-null  int64
#  35  RiskScore                   20000 non-null  float64
# dtypes: float64(9), int64(21), str(6)
# memory usage: 6.4 MB

# %%
string_df = df.select_dtypes(include=['str']).columns.tolist()
string_df
# Out:
# ['ApplicationDate',
#  'EmploymentStatus',
#  'EducationLevel',
#  'MaritalStatus',
#  'HomeOwnershipStatus',
#  'LoanPurpose']

# %%
df.drop(columns=['ApplicationDate'])
# Out:
#        Age  AnnualIncome  CreditScore EmploymentStatus EducationLevel  \
# 0       45         39948          617         Employed         Master
# 1       38         39709          628         Employed      Associate
# 2       47         40724          570         Employed       Bachelor
# 3       58         69084          545         Employed    High School
# 4       37        103264          594         Employed      Associate
# ...    ...           ...          ...              ...            ...
# 19995   44         30180          587         Employed    High School
# 19996   56         49246          567         Employed      Associate
# 19997   44         48958          645         Employed       Bachelor
# 19998   60         41025          560         Employed    High School
# 19999   20         53227          574         Employed      Associate
#
#        Experience  LoanAmount  LoanDuration MaritalStatus  NumberOfDependents  \
# 0              22       13152            48       Married                   2
# 1              15       26045            48        Single                   1
# 2              26       17627            36       Married                   2
# 3              34       37898            96        Single                   1
# 4              17        9184            36       Married                   1
# ...           ...         ...           ...           ...                 ...
# 19995          19       24521            36       Married                   3
# 19996          33       25818            36       Married                   5
# 19997          20       37033            72       Married                   3
# 19998          36       14760            72       Married                   3
# 19999           0       32055            48       Married                   0
#
#        ... MonthlyIncome  UtilityBillsPaymentHistory  JobTenure  NetWorth  \
# 0      ...   3329.000000                    0.724972         11    126928
# 1      ...   3309.083333                    0.935132          3     43609
# 2      ...   3393.666667                    0.872241          6      5205
# 3      ...   5757.000000                    0.896155          5     99452
# 4      ...   8605.333333                    0.941369          5    227019
# ...    ...           ...                         ...        ...       ...
# 19995  ...   2515.000000                    0.826217          1     55327
# 19996  ...   4103.833333                    0.816618          3     64002
# 19997  ...   4079.833333                    0.887216          3    103663
# 19998  ...   3418.750000                    0.843787          5     10600
# 19999  ...   4435.583333                    0.853801          5     41372
#
#        BaseInterestRate  InterestRate  MonthlyLoanPayment  \
# 0              0.199652      0.227590          419.805992
# 1              0.207045      0.201077          794.054238
# 2              0.217627      0.212548          666.406688
# 3              0.300398      0.300911         1047.506980
# 4              0.197184      0.175990          330.179140
# ...                 ...           ...                 ...
# 19995          0.216021      0.195574          905.767712
# 19996          0.227318      0.199168          958.395633
# 19997          0.229533      0.226766          945.427454
# 19998          0.249760      0.264873          411.168284
# 19999          0.240055      0.242693         1049.830407
#
#       TotalDebtToIncomeRatio  LoanApproved  RiskScore
# 0                   0.181077             0       49.0
# 1                   0.389852             0       52.0
# 2                   0.462157             0       52.0
# 3                   0.313098             0       54.0
# 4                   0.070210             1       36.0
# ...                      ...           ...        ...
# 19995               0.627741             0       55.0
# 19996               0.334418             0       54.0
# 19997               0.357227             0       45.0
# 19998               0.408678             0       59.0
# 19999               0.298006             0       59.0
#
# [20000 rows x 35 columns]

# %%
df = pd.get_dummies(df, columns=string_df)

len(df.columns)
# Out:
# 20051

# %%
X = df.drop(columns=['RiskScore',"LoanApproved"])
feature_names = X.columns

scaler = StandardScaler()   

X= scaler.fit_transform(X)
y = df["RiskScore"]

# %%
# X_train, y_train, X_test, y_test = train_test_split(X,y,test_size=0.25)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
len(y_train)
# Out:
# 16000

# %%
# model = LinearRegression()
# model.fit(X_train,y_train)

# %%
# predict = model.predict(X_test)
# rmse = root_mean_squared_error(y_test, predict)

# %%
# print(rmse)

# %%
df['RiskScore'].describe()
# Out:
# count    20000.000000
# mean        50.766780
# std          7.778262
# min         28.800000
# 25%         46.000000
# 50%         52.000000
# 75%         56.000000
# max         84.000000
# Name: RiskScore, dtype: float64

# %%
# accuracy = r2_score(y_test,predict)

# %%
# print(accuracy)

# %%
def training(model):
    predict = model.predict(X_test)
    rmse = root_mean_squared_error(y_test, predict)
    print(rmse)
    accuracy = r2_score(y_test,predict)
    print(accuracy)
    return model

def feature_selection(model):
    importances = model.feature_importances_
    feature_ranking = pd.Series(importances, index=feature_names)
    feature_ranking = feature_ranking.sort_values(ascending=True)

    for feature, importance in feature_ranking.items():
        if importance != 0:
            print(feature, importance)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
training(model)
# Out:
# 4.74249572594002
# 0.62077704591202
# LinearRegression()

# %%
model = XGBRegressor(n_estimators=1100, learning_rate = 0.03, max_depth = 3, objective="reg:squarederror",)
model.fit(X_train, y_train, verbose=False)
feature_selection(model)
training(model)
# Out:
# ApplicationDate_2035-12-31 0.0003805242304224521
# ApplicationDate_2050-10-11 0.000381429708795622
# ApplicationDate_2069-08-27 0.00038155235233716667
# ApplicationDate_2062-10-28 0.00038163873250596225
# ApplicationDate_2045-06-28 0.00038258996210061014
# ApplicationDate_2066-11-09 0.00038260509609244764
# ApplicationDate_2052-12-12 0.00038264028262346983
# ApplicationDate_2062-02-14 0.00038294505793601274
# ApplicationDate_2039-11-17 0.0003831037611234933
# ApplicationDate_2024-08-18 0.00038421573117375374
# ApplicationDate_2020-05-07 0.0003853902453556657
# ApplicationDate_2034-05-16 0.0003858021809719503
# ApplicationDate_2071-01-13 0.0003858990967273712
# ApplicationDate_2033-08-27 0.0003863955207634717
# ApplicationDate_2058-07-27 0.00038718542782589793
# ApplicationDate_2036-04-16 0.00038721825694665313
# ApplicationDate_2042-08-18 0.0003872488741762936
# ApplicationDate_2069-06-06 0.00038735565613023937
# ApplicationDate_2043-04-27 0.0003878489078488201
# ApplicationDate_2057-08-22 0.0003878996358253062
# ApplicationDate_2069-03-26 0.00038795979344286025
# ApplicationDate_2021-10-09 0.00038818534812889993
# ApplicationDate_2044-06-18 0.0003883256867993623
# ApplicationDate_2018-12-29 0.0003886048507411033
# ApplicationDate_2025-03-07 0.00038872897857800126
# ApplicationDate_2036-03-28 0.00038878756458871067
# ApplicationDate_2036-06-22 0.0003903607721440494
# ApplicationDate_2020-05-17 0.0003906905185431242
# ApplicationDate_2035-08-29 0.0003916328423656523
# ApplicationDate_2019-07-18 0.0003923754848074168
# ApplicationDate_2037-02-05 0.00039288512198254466
# ApplicationDate_2059-06-19 0.0003940628084819764
# ApplicationDate_2052-04-14 0.00039531910442747176
# ApplicationDate_2059-07-23 0.0005203310283832252
# ApplicationDate_2037-07-01 0.0005204147309996188
# ApplicationDate_2024-10-28 0.0005221181781962514
# ApplicationDate_2041-05-29 0.0005283760838210583
# ApplicationDate_2024-03-29 0.0005285145016387105
# ApplicationDate_2060-07-17 0.0005311635904945433
# LoanPurpose_Debt Consolidation 0.0005367278354242444
# EducationLevel_Bachelor 0.0005507501773536205
# ApplicationDate_2039-05-13 0.0005512411589734256
# ApplicationDate_2021-05-25 0.0005513826035894454
# ApplicationDate_2056-04-05 0.0005520725389942527
# ApplicationDate_2052-09-15 0.0005598973366431892
# ApplicationDate_2042-08-23 0.0006138862809166312
# ApplicationDate_2020-02-28 0.0006530375103466213
# SavingsAccountBalance 0.0006788455648347735
# NumberOfCreditInquiries 0.0006998749449849129
# NumberOfOpenCreditLines 0.0006999260513111949
# CheckingAccountBalance 0.000701639917679131
# MaritalStatus_Widowed 0.0007581686950288713
# TotalLiabilities 0.0008674776763655245
# UtilityBillsPaymentHistory 0.0009145456133410335
# ApplicationDate_2070-09-04 0.0009678491624072194
# HomeOwnershipStatus_Own 0.0011059190146625042
# HomeOwnershipStatus_Rent 0.0011452912585809827
# MonthlyLoanPayment 0.001203202293254435
# NumberOfDependents 0.0012216615723446012
# JobTenure 0.0012823018478229642
# HomeOwnershipStatus_Other 0.0013001903425902128
# MonthlyDebtPayments 0.0013260184787213802
# PaymentHistory 0.0013589796144515276
# LoanAmount 0.0015697430353611708
# LoanPurpose_Other 0.0017159967683255672
# EducationLevel_Associate 0.0019396631978452206
# Age 0.0019453391432762146
# HomeOwnershipStatus_Mortgage 0.002241366310045123
# LoanDuration 0.003379207104444504
# EducationLevel_Doctorate 0.0035408399999141693
# Experience 0.0037887701764702797
# EmploymentStatus_Self-Employed 0.0051536257378757
# EducationLevel_High School 0.005691330414265394
# EmploymentStatus_Unemployed 0.0057823373936116695
# EducationLevel_Master 0.006116339471191168
# TotalAssets 0.007953683845698833
# BaseInterestRate 0.010793942958116531
# CreditCardUtilizationRate 0.011999393813312054
# InterestRate 0.029408689588308334
# EmploymentStatus_Employed 0.0339900366961956
# LengthOfCreditHistory 0.0360993854701519
# CreditScore 0.04538094252347946
# TotalDebtToIncomeRatio 0.051903292536735535
# AnnualIncome 0.07571544498205185
# MonthlyIncome 0.0765613541007042
# NetWorth 0.08636438101530075
# DebtToIncomeRatio 0.10017206519842148
# PreviousLoanDefaults 0.10141843557357788
# BankruptcyHistory 0.20212136209011078
# 2.466980864920423
# 0.8973846614111587
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.03, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=1100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
training(model)
# Out:
# 2.466980864920423
# 0.8973846614111587
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.03, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=1100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
# # Feature importance
# importances = model.feature_importances_
# feature_ranking = pd.Series(importances, index=feature_names)
# feature_ranking = feature_ranking.sort_values(ascending=True)

# for feature, importance in feature_ranking.items():
#     if importance != 0:
#         print(feature, importance)

# %%
# predict = model.predict(X_test)
# rmse = root_mean_squared_error(y_test, predict)
# print(rmse)
# accuracy = r2_score(y_test,predict)
# print(accuracy)
